# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
import requests
import pandas as pd
import json

# %%
from stackapi import StackAPI

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
SITE = StackAPI('stackoverflow')
from datetime import datetime
result = SITE.fetch('questions', fromdate=datetime(2019,12,1), todate=datetime(2019,12,31))
result
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['c#', 'rsa', 'digital-signature'],
#    'owner': {'reputation': 378,
#     'user_id': 4054386,
#     'user_type': 'registered',
#     'accept_rate': 70,
#     'profile_image': 'https://lh3.googleusercontent.com/-49Sb-Yaen8c/AAAAAAAAAAI/AAAAAAAAAEM/ch0v3Ojov3Y/photo.jpg?sz=128',
#     'display_name': 'Vic F',
#     'link': 'https://stackoverflow.com/users/4054386/vic-f'},
#    'is_answered': False,
#    'view_count': 98,
#    'bounty_amount': 50,
#    'bounty_closes_date': 1580874659,
#    'answer_count': 1,
#    'score': -1,
#    'last_activity_date': 1580380910,
#    'creation_date': 1575387160,
#    'last_edit_date': 1580270390,
#    'question_id': 59160463,
#    'link': 'https://stackoverflow.com/questions/59160463/verifying-digital-signature',
#    'title': 'Verifying digital signature'},
# ...

# %%
result_list=result['items']

# %%
result_list
# Out:
# [{'tags': ['c#', 'rsa', 'digital-signature'],
#   'owner': {'reputation': 378,
#    'user_id': 4054386,
#    'user_type': 'registered',
#    'accept_rate': 70,
#    'profile_image': 'https://lh3.googleusercontent.com/-49Sb-Yaen8c/AAAAAAAAAAI/AAAAAAAAAEM/ch0v3Ojov3Y/photo.jpg?sz=128',
#    'display_name': 'Vic F',
#    'link': 'https://stackoverflow.com/users/4054386/vic-f'},
#   'is_answered': False,
#   'view_count': 98,
#   'bounty_amount': 50,
#   'bounty_closes_date': 1580874659,
#   'answer_count': 1,
#   'score': -1,
#   'last_activity_date': 1580380910,
#   'creation_date': 1575387160,
#   'last_edit_date': 1580270390,
#   'question_id': 59160463,
#   'link': 'https://stackoverflow.com/questions/59160463/verifying-digital-signature',
#   'title': 'Verifying digital signature'},
#  {'tags': ['c++', 'web-services', 'soap', 'ws-security', 'wwsapi'],
#   'owner': {'reputation': 11,
#    'user_id': 12545068,
#    'user_type': 'registered',
# ...

# %%
for question in result_list:
    print(question['title'])
    print("------------")
# Out:
# DocuSign Java API envelopesApi.getDocument return NULL exception
# ------------
# AWS SNS Subscription Filter policy checking a key in Message Attributes does NOT exist - possible?
# ------------
# How to mock streams that are created using supplier and used twice?
# ------------
# Testing if button changes state, or if component appears (React)
# ------------
# How to display data from a service in an Angular Datatable
# ------------
# NetSuite SuiteTalk REST Web Services - Invalid Login Attempt
# ------------
# Why do I get a verification error when trying to upload my code to my Arduino?
# ------------
# SecurityError: Failed to construct &#39;WebSocket, when I upload react js application in heroku server, Local all file are running fine
# ------------
# In ngx-editor how to insert html block at cursor placement when clicked on a button
# ------------
# Satellite Tile quality HERE SDK lite
# ------------
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here - i changed it to this week as there were not enough data for today
SITE = StackAPI('stackoverflow')
from datetime import datetime
result2 = SITE.fetch('questions', fromdate=datetime(2020,1,22), todate=datetime(2020,1,29), min=5, sort='votes', tagged='python')
result2
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['python', 'python-3.x'],
#    'owner': {'reputation': 40918,
#     'user_id': 7207392,
#     'user_type': 'registered',
#     'accept_rate': 73,
#     'profile_image': 'https://www.gravatar.com/avatar/dadc9567dde5f02b09a29695eca1ce40?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Paul Panzer',
#     'link': 'https://stackoverflow.com/users/7207392/paul-panzer'},
#    'is_answered': True,
#    'view_count': 926,
#    'bounty_amount': 100,
#    'bounty_closes_date': 1580860438,
#    'accepted_answer_id': 59923762,
#    'answer_count': 1,
#    'score': 16,
#    'last_activity_date': 1580255638,
#    'creation_date': 1580081456,
#    'last_edit_date': 1580082236,
#    'question_id': 59923717,
#    'link': 'https://stackoverflow.com/questions/59923717/is-there-a-way-of-subclassing-from-dict-and-collections-abc-mutablemapping-toget',
# ...

# %%
best_voted_question=result['items'][0]['title']
best_voted_question
# Out:
# 'Verifying digital signature'

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
SITE = StackAPI('stackoverflow')
from datetime import datetime
result3 = SITE.fetch('answers')
result3
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 1421,
#     'user_id': 9260725,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a4cb81681d77163e3422870b23ddbafc?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'xdtTransform',
#     'link': 'https://stackoverflow.com/users/9260725/xdttransform'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1580381267,
#    'last_edit_date': 1580381267,
#    'creation_date': 1580379573,
#    'answer_id': 59983717,
#    'question_id': 59982752},
#   {'owner': {'reputation': 3567,
#     'user_id': 3894930,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/4NZyT.jpg?s=128&g=1',
#     'display_name': 'Dhaval Solanki',
#     'link': 'https://stackoverflow.com/users/3894930/dhaval-solanki'},
#    'is_accepted': False,
#    'score': 0,
# ...

# %%
result_list3=result3['items']

# %%
for answers in result_list3:
    if answers['answer_id'] == 6473:
        print("ok")
        
#no answers with this id
